# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data
df = pd.read_csv('../../dataset/nou_hearings_full_text.csv')

# %%
from pandas import isna


pd.DataFrame(df["actor_label"].unique())
# Out:
#                         0
# 0         Interessegruppe
# 1   Offentlig forvaltning
# 2                 Bedrift
# 3          Politisk parti
# 4  Frivillig organisasjon
# 5            Privatperson
# 6   Akademisk institusjon

# %%
# Find median length of a text by each actor_label
# Tokenize the text


df['text_length'] = df['text'].apply(lambda x: len(x.split(' ')))
df.groupby('actor_label')['text_length'].median().plot(kind='bar')
# Out:
# <Axes: xlabel='actor_label'>

# %%
df.groupby('actor_label').size().plot(kind='bar')
# Out:
# <Axes: xlabel='actor_label'>

# %% [markdown]
# ## Bert Model Confusion matrix raw paragraphs

# %%
# import model
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues')
